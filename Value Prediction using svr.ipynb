# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import PowerTransformer, RobustScaler
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error

# %%
train_data = pd.read_csv('train.csv')
train_data.head(10)
# Out:
#      id                Name  Aerial Duels won  Age  Assists  \
# 0   917    Lassine Sinayoko               1.3   23     0.11
# 1   432          Emil Ceide               0.2   21     0.17
# 2   948        Linton Maina               0.0   24     0.28
# 3   989  Luis Javier Suarez               2.1   25     0.24
# 4   887         Kim Min-jae               2.9   26     0.05
# 5   983       Lucas Vazquez               0.1   32     0.13
# 6  1531     Stefan Bajcetic               1.3   18     0.00
# 7  1125      Mehdi Bourabia               0.7   32     0.10
# 8   277  Christian Norgaard               0.9   29     0.15
# 9  1318               Pedri               0.2   20     0.04
#
#    Attacking options created  Attempted Passes  Blocks  Clearances   Country  \
# 0                       3.68              31.8    0.69        0.97      Mali
# 1                       3.49              29.5    0.52        0.00    Norway
# 2                       2.99              27.5    0.76        0.36   Germany
# 3                       2.44              23.5    0.76        0.81  Colombia
# 4                       1.19              80.4    1.06        3.64       NaN
# 5                       3.44              73.2    0.74        1.14     Spain
# 6                       2.08              47.3    0.99        0.57     Spain
# 7                       2.73              41.6    1.27        1.85   Morocco
# 8                       1.71              41.5    1.63        2.09   Denmark
# 9                       4.22              65.4    1.27        0.34     Spain
#
#    ...  Progressive Passes  Progressive Carries  Shots  Successful Dribbles  \
# 0  ...                4.24                 2.81   2.41                 1.61
# 1  ...                3.32                 6.47   1.75                 1.40
# 2  ...                2.45                 3.62   1.41                 0.88
# 3  ...                1.80                 1.66   2.89                 1.09
# 4  ...                4.81                 1.20   0.21                 0.14
# 5  ...                3.95                 2.61   0.94                 1.07
# 6  ...                4.25                 1.42   1.13                 1.13
# 7  ...                3.67                 1.20   1.07                 0.91
# 8  ...                3.73                 0.20   0.97                 0.41
# 9  ...                8.15                 3.09   1.08                 1.64
#
#    Touches in attacking penalty area  Tackles  \
# 0                               4.36     1.89
# 1                               6.82     0.87
# 2                               3.98     0.72
# 3                               4.08     1.04
# 4                               0.70     1.57
# 5                               3.41     2.54
# 6                               0.71     2.13
# 7                               0.68     1.33
# 8                               2.14     2.65
# 9                               2.64     1.71
#
#    Value at beginning of 2020/21 season  Value at beginning of 2021/22 season  \
# 0                                   0.2                                   0.8
# 1                                   0.4                                   NaN
# 2                                   7.5                                   2.5
# 3                                  10.0                                  10.0
# 4                                   2.0                                   6.5
# 5                                  10.0                                  12.0
# 6                                   NaN                                   NaN
# 7                                   3.0                                   1.6
# 8                                   4.0                                   8.0
# 9                                  30.0                                  80.0
#
#    Value at beginning of 2022/23 season  Value at beginning of 2023/24 season
# 0                                   1.3                                   1.2
# 1                                   1.0                                   2.5
# 2                                   1.8                                   6.0
# 3                                   9.0                                   8.0
# 4                                   9.0                                  60.0
# 5                                  12.0                                   8.0
# 6                                   1.0                                  13.0
# 7                                   1.0                                   1.3
# 8                                  10.0                                  16.0
# 9                                  80.0                                 100.0
#
# [10 rows x 26 columns]

# %%
test_data = pd.read_csv('test.csv')
test_data.head(10)
# Out:
#      id  Aerial Duels won  Age  Assists  Attacking options created  \
# 0   705               2.6   28     0.03                       0.95
# 1   809               0.3   28     0.10                       3.22
# 2  1432               0.7   26     0.03                       2.34
# 3   173               1.6   26     0.12                       1.98
# 4   513               0.4   30     0.38                       5.12
# 5  1649               0.3   17     0.00                       2.15
# 6   818               1.2   23     0.22                       2.30
# 7   261               1.7   26     0.00                       1.97
# 8   405               2.0   25     0.00                       0.68
# 9  1399               1.9   28     0.05                       1.65
#
#    Attempted Passes  Blocks  Clearances      Country  \
# 0              47.2    1.13        3.44     Cameroon
# 1              50.5    0.79        1.73      Croatia
# 2              47.5    1.08        1.56         Mali
# 3              50.2    1.40        2.32     Portugal
# 4              46.3    1.04        1.15      Austria
# 5              58.9    0.98        1.51       France
# 6              52.2    1.16        3.36        Spain
# 7              35.5    1.34        1.30  Switzerland
# 8              61.8    2.03        3.68       Brazil
# 9              53.5    1.28        1.87      Germany
#
#    Expected Goal Contributions  ...  Progressive Passes Rec  \
# 0                         0.01  ...                    0.69
# 1                         0.18  ...                    3.62
# 2                         0.08  ...                    1.22
# 3                         0.22  ...                    7.50
# 4                         0.35  ...                    5.64
# 5                         0.05  ...                    5.42
# 6                         0.18  ...                    5.64
# 7                         0.04  ...                    2.21
# 8                         0.02  ...                    0.50
# 9                         0.05  ...                    0.29
#
#    Progressive Passes  Progressive Carries  Shots  Successful Dribbles  \
# 0                4.04                 0.58   0.35                 0.32
# 1                3.96                 1.78   0.69                 0.74
# 2                5.72                 2.00   0.81                 1.69
# 3                3.11                 3.05   0.55                 0.61
# 4                6.10                 2.46   1.96                 1.27
# 5                3.11                 2.22   0.80                 1.60
# 6                4.03                 1.88   1.12                 0.58
# 7                3.77                 0.65   0.83                 0.15
# 8                3.00                 0.91   0.68                 0.37
# 9                3.52                 0.59   1.07                 0.24
#
#    Touches in attacking penalty area  Tackles  \
# 0                               0.95     1.53
# 1                               0.84     1.34
# 2                               0.64     1.49
# 3                               2.87     2.32
# 4                               1.73     0.81
# 5                               1.96     1.69
# 6                               2.06     1.52
# 7                               1.59     1.99
# 8                               0.99     1.46
# 9                               0.77     2.21
#
#    Value at beginning of 2020/21 season  Value at beginning of 2021/22 season  \
# 0                                   2.5                                   3.0
# 1                                   1.7                                   4.0
# 2                                   1.2                                   3.0
# 3                                   4.8                                   3.5
# 4                                   4.0                                   3.5
# 5                                   NaN                                   NaN
# 6                                   4.0                                   6.0
# 7                                   0.7                                   2.0
# 8                                  40.0                                  60.0
# 9                                   4.0                                  11.0
#
#    Value at beginning of 2022/23 season
# 0                                   4.0
# 1                                   7.0
# 2                                   3.5
# 3                                   3.0
# 4                                   3.5
# 5                                   5.0
# 6                                   5.0
# 7                                   2.5
# 8                                  60.0
# 9                                  13.0
#
# [10 rows x 24 columns]

# %%
#resolving duplicates and filling empty values
train_data.fillna(train_data.mean(numeric_only=True), inplace=True)
train_data.drop_duplicates(inplace=True) 

test_data.fillna(test_data.mean(numeric_only=True), inplace=True)
test_data.drop_duplicates(inplace=True)

# %%
X_train = train_data.drop(['Name','Country','Value at beginning of 2023/24 season'],axis=1)

# %%
X_train
# Out:
#         id  Aerial Duels won  Age  Assists  Attacking options created  \
# 0      917               1.3   23     0.11                       3.68
# 1      432               0.2   21     0.17                       3.49
# 2      948               0.0   24     0.28                       2.99
# 3      989               2.1   25     0.24                       2.44
# 4      887               2.9   26     0.05                       1.19
# ...    ...               ...  ...      ...                        ...
# 1288  1130               0.5   28     0.26                       3.41
# 1289  1294               0.3   31     0.00                       4.01
# 1290   860               0.7   24     0.04                       2.61
# 1291  1459               0.4   23     0.03                       1.63
# 1292  1126               0.4   31     0.14                       2.15
#
#       Attempted Passes  Blocks  Clearances  Expected Goal Contributions  \
# 0                 31.8    0.69        0.97                         0.16
# 1                 29.5    0.52        0.00                         0.25
# 2                 27.5    0.76        0.36                         0.26
# 3                 23.5    0.76        0.81                         0.14
# 4                 80.4    1.06        3.64                         0.04
# ...                ...     ...         ...                          ...
# 1288              59.8    0.73        1.62                         0.20
# 1289              42.4    0.81        0.29                         0.17
# 1290              31.0    1.65        0.25                         0.14
# 1291              61.6    1.18        0.81                         0.05
# 1292              37.3    1.91        1.64                         0.11
#
#       Interceptions  ...  Progressive Passes Rec  Progressive Passes  \
# 0               1.1  ...                    8.60                4.24
# 1               0.2  ...                    8.21                3.32
# 2               0.2  ...                    6.95                2.45
# 3               0.3  ...                    5.46                1.80
# 4               1.5  ...                    0.19                4.81
# ...             ...  ...                     ...                 ...
# 1288            0.5  ...                    4.24                6.54
# 1289            0.3  ...                    6.97                4.33
# 1290            0.4  ...                    4.22                4.65
# 1291            1.2  ...                    1.37                5.13
# 1292            3.1  ...                    4.24                2.46
#
#       Progressive Carries  Shots  Successful Dribbles  \
# 0                    2.81   2.41                 1.61
# 1                    6.47   1.75                 1.40
# 2                    3.62   1.41                 0.88
# 3                    1.66   2.89                 1.09
# 4                    1.20   0.21                 0.14
# ...                   ...    ...                  ...
# 1288                 1.57   1.20                 0.63
# 1289                 1.98   2.13                 0.29
# 1290                 3.42   1.18                 2.11
# 1291                 1.03   0.40                 0.90
# 1292                 1.23   1.09                 0.55
#
#       Touches in attacking penalty area  Tackles  \
# 0                                  4.36     1.89
# 1                                  6.82     0.87
# 2                                  3.98     0.72
# 3                                  4.08     1.04
# 4                                  0.70     1.57
# ...                                 ...      ...
# 1288                               2.04     1.15
# 1289                               2.94     1.32
# 1290                               2.28     3.00
# 1291                               0.50     1.43
# 1292                               1.50     1.64
#
#       Value at beginning of 2020/21 season  \
# 0                                      0.2
# 1                                      0.4
# 2                                      7.5
# 3                                     10.0
# 4                                      2.0
# ...                                    ...
# 1288                                   5.0
# 1289                                  25.0
# 1290                                   3.5
# 1291                                   0.3
# 1292                                   1.0
#
#       Value at beginning of 2021/22 season  \
# 0                                 0.800000
# 1                                12.593151
# 2                                 2.500000
# 3                                10.000000
# 4                                 6.500000
# ...                                    ...
# 1288                              4.500000
# 1289                             25.000000
# 1290                              3.300000
# 1291                              2.000000
# 1292                              1.000000
#
#       Value at beginning of 2022/23 season
# 0                                      1.3
# 1                                      1.0
# 2                                      1.8
# 3                                      9.0
# 4                                      9.0
# ...                                    ...
# 1288                                   5.5
# 1289                                  25.0
# 1290                                   3.5
# 1291                                   2.5
# 1292                                   1.0
#
# [1293 rows x 23 columns]

# %%
y_train=train_data['Value at beginning of 2023/24 season']

# %%
X_test = test_data.drop(['Country'],axis=1)

# %%
X_test
# Out:
#        id  Aerial Duels won  Age  Assists  Attacking options created  \
# 0     705               2.6   28     0.03                       0.95
# 1     809               0.3   28     0.10                       3.22
# 2    1432               0.7   26     0.03                       2.34
# 3     173               1.6   26     0.12                       1.98
# 4     513               0.4   30     0.38                       5.12
# ..    ...               ...  ...      ...                        ...
# 404  1220               0.9   28     0.00                       0.60
# 405   478               0.6   28     0.10                       1.40
# 406   798               2.9   33     0.00                       1.12
# 407  1563               1.5   26     0.00                       2.43
# 408  1667               1.8   25     0.06                       0.78
#
#      Attempted Passes  Blocks  Clearances  Expected Goal Contributions  \
# 0                47.2    1.13        3.44                         0.01
# 1                50.5    0.79        1.73                         0.18
# 2                47.5    1.08        1.56                         0.08
# 3                50.2    1.40        2.32                         0.22
# 4                46.3    1.04        1.15                         0.35
# ..                ...     ...         ...                          ...
# 404              38.0    1.95        2.41                         0.01
# 405              43.3    1.50        2.62                         0.04
# 406              61.4    1.30        2.37                         0.04
# 407              34.2    1.00        1.22                         0.05
# 408              57.8    1.74        3.89                         0.02
#
#      Interceptions  ...  Progressive Passes Rec  Progressive Passes  \
# 0              2.0  ...                    0.69                4.04
# 1              0.8  ...                    3.62                3.96
# 2              1.7  ...                    1.22                5.72
# 3              0.6  ...                    7.50                3.11
# 4              1.3  ...                    5.64                6.10
# ..             ...  ...                     ...                 ...
# 404            1.2  ...                    1.49                3.10
# 405            1.2  ...                    2.44                2.65
# 406            3.4  ...                    0.36                3.44
# 407            1.1  ...                    8.40                2.74
# 408            1.5  ...                    0.09                2.41
#
#      Progressive Carries  Shots  Successful Dribbles  \
# 0                   0.58   0.35                 0.32
# 1                   1.78   0.69                 0.74
# 2                   2.00   0.81                 1.69
# 3                   3.05   0.55                 0.61
# 4                   2.46   1.96                 1.27
# ..                   ...    ...                  ...
# 404                 0.80   0.23                 0.00
# 405                 1.74   0.21                 0.59
# 406                 0.36   0.71                 0.24
# 407                 2.61   2.00                 1.39
# 408                 0.35   0.38                 0.29
#
#      Touches in attacking penalty area  Tackles  \
# 0                                 0.95     1.53
# 1                                 0.84     1.34
# 2                                 0.64     1.49
# 3                                 2.87     2.32
# 4                                 1.73     0.81
# ..                                 ...      ...
# 404                               0.23     2.76
# 405                               1.01     1.60
# 406                               1.07     2.73
# 407                               2.61     1.44
# 408                               0.59     1.68
#
#      Value at beginning of 2020/21 season  \
# 0                                     2.5
# 1                                     1.7
# 2                                     1.2
# 3                                     4.8
# 4                                     4.0
# ..                                    ...
# 404                                   4.2
# 405                                   3.5
# 406                                  10.0
# 407                                   1.0
# 408                                   3.0
#
#      Value at beginning of 2021/22 season  \
# 0                                     3.0
# 1                                     4.0
# 2                                     3.0
# 3                                     3.5
# 4                                     3.5
# ..                                    ...
# 404                                   3.0
# 405                                   2.5
# 406                                   9.0
# 407                                   1.5
# 408                                   8.0
#
#      Value at beginning of 2022/23 season
# 0                                     4.0
# 1                                     7.0
# 2                                     3.5
# 3                                     3.0
# 4                                     3.5
# ..                                    ...
# 404                                   2.0
# 405                                   3.0
# 406                                   7.5
# 407                                   3.0
# 408                                  10.0
#
# [409 rows x 23 columns]

# %%
y_test=train_data['Value at beginning of 2023/24 season']
np.random.seed(42)  # For reproducibility
y_test = y_test.sample(n=409, random_state=42)

# %%
#X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.25,random_state=0)

# %%
#Pre-processing data

#Making the distribution of the features more Gaussian
pt = PowerTransformer()

X_train_transformed = pt.fit_transform(X_train)
X_test_transformed = pt.transform(X_test)


#Scaling the data

#Initiating Robust Scaler
rs= RobustScaler()

#Standardizing numerical columns
X_train_scaled = rs.fit_transform(X_train_transformed)
X_test_scaled = rs.transform(X_test_transformed)

# %%
#Initiating Support Vector Regressor to calculate feature importance
svr = SVR(kernel='linear')
svr.fit(X_train_scaled,y_train);

# %%
cross_val_train = cross_val_score(svr, X_train_scaled, y_train, scoring="neg_root_mean_squared_error",cv=5)
cross_val_test = cross_val_score(svr, X_test_scaled, y_test, scoring="neg_root_mean_squared_error",cv=5)

# %%
#Train Results
cross_val_train_mean = round(-(cross_val_train.mean()),2)
cross_val_train_max = round(-(cross_val_train.min()),2)
cross_val_train_min = round(-(cross_val_train.max()),2)

#Test Results
cross_val_test_mean = round(-(cross_val_test.mean()),2)
cross_val_test_max = round(-(cross_val_test.min()),2)
cross_val_test_min = round(-(cross_val_test.max()),2)

#Creating a Dataframe to display Validation Results
results = pd.DataFrame(columns=['Train/Test','Avg RMSE','Max RMSE','Min RMSE'])
results.loc[0] = ['Train',cross_val_train_mean,cross_val_train_max,cross_val_train_min]
results.loc[1] = ['Test', cross_val_test_mean, cross_val_test_max, cross_val_test_min]

# %%
fig, ax = plt.subplots(figsize=(20,12))

x_ticks = list(range(0,max([results.iloc[0][2],(round(results.iloc[1][2])+1000000)]),2500000))
y_ticks = [1,2,3,4]
y_labels = ['Train Max RMSE','Train Min RMSE','Test Max RMSE','Test Min RMSE']

train_max_pos = 1
train_max = results.iloc[0][2]
ax.barh(train_max_pos,train_max,color='navy')

train_min_pos = 2
train_min = results.iloc[0][3]
ax.barh(train_min_pos,train_min,color='navy')

test_max_pos = 3
test_max = results.iloc[1][2]
ax.barh(test_max_pos,test_max,color='orange')

test_min_pos = 4
test_min = results.iloc[1][3]
ax.barh(test_min_pos,test_min,color='orange')

ax.axvline(x = results.iloc[0][1],label = 'Average Train RMSE',color='dodgerblue')
ax.axvline(x = results.iloc[1][1],label = 'Average Test RMSE',color='red')

ax.set_yticks(y_ticks)
ax.set_yticklabels(y_labels)
ax.set_xticks(x_ticks)
ax.set_xticklabels([f'£ {a}' for a in x_ticks])
ax.set_xlabel('Error Value',fontsize=20)
ax.set_ylabel('Validation Results',fontsize=20)
ax.set_title('Comparing Train and Test RMSEs for Default Hyperparameter SVR Model',fontsize=30)
ax.legend(fontsize=15);

# %%
fig,ax = plt.subplots(figsize=(20,12))

pd.Series(abs(svr.coef_[0]), index=X_train.columns).nlargest(10).plot(kind='barh');

# %%
fig,ax = plt.subplots(figsize=(20,12))

pd.Series(abs(svr.coef_[0]), index=X_test.columns).nlargest(10).plot(kind='barh');

# %%
#Creating a list of top features for train data
top_features_train = list(pd.Series(abs(svr.coef_[0]), index=X_train.columns).nlargest(10).keys())

# %%
#Creating a list of top features for test data
top_features_test = list(pd.Series(abs(svr.coef_[0]), index=X_test.columns).nlargest(10).keys())

# %%
X = df.drop(['Name','Country','Value at beginning of 2023/24 season'],axis=1)[top_features]
y = df['Value at beginning of 2023/24 season']

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.25,random_state=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 X = df.drop(['Name','Country','Value at beginning of 2023/24 season'],axis=1)[top_features]
#       2 y = df['Value at beginning of 2023/24 season']
#       4 X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.25,random_state=0)
#
# NameError: name 'df' is not defined

# %%
X_train = train_data.drop(['Name','Country','Value at beginning of 2023/24 season'],axis=1)[top_features_train]
y_train=train_data['Value at beginning of 2023/24 season']
X_test = test_data.drop(['Country'],axis=1)[top_features_test]
y_test=train_data['Value at beginning of 2023/24 season']
np.random.seed(42)  # For reproducibility
y_test = y_test.sample(n=409, random_state=42)

# %%
#Making the distribution of the features more Gaussian
pt = PowerTransformer()

X_train_transformed = pt.fit_transform(X_train)
X_test_transformed = pt.transform(X_test)

#Scaling the data

#Initiating Robust Scaler
rs= RobustScaler()

#Standardizing numerical columns
X_train_scaled = rs.fit_transform(X_train_transformed)
X_test_scaled = rs.transform(X_test_transformed)

# %%
# Create the parameter grid based on the results of random search 
parameters = { 'C':[0.1,1,100,1000],
              'kernel':['rbf','poly','sigmoid','linear'],
              'degree':[1,2,3,4,5,6],
              'gamma': [1, 0.1, 0.01, 0.001, 0.0001]}

# %%
import multiprocessing
n_jobs = multiprocessing.cpu_count()-1
# Instantiate the grid search
grid_search = GridSearchCV(estimator = svr, param_grid = parameters, 
                          cv = 5, n_jobs = n_jobs, verbose = 2)

# %%
grid_search.fit(X_train_scaled,y_train)
# Out:
# Fitting 5 folds for each of 480 candidates, totalling 2400 fits

# %%
#grid_search.best_params_

# %%
param_values = list((grid_search.best_params_).values())

# %%
param_values
# Out:
# [1000, 1, 0.1, 'rbf']

# %%
# Traning model with all features using best SVR Hyperparameters
svr_Grid = SVR(C = 1000,
              degree = 1,
              gamma = 0.1,
              kernel='rbf')

svr_Grid.fit(X_train_scaled,y_train);

# %%
cross_val_train = cross_val_score(svr_Grid, X_train_scaled, y_train, scoring="neg_root_mean_squared_error",cv=5)
cross_val_test = cross_val_score(svr_Grid, X_test_scaled, y_test, scoring="neg_root_mean_squared_error",cv=5)

# %%
#Train Results
cross_val_train_mean = round(-(cross_val_train.mean()),2)
cross_val_train_max = round(-(cross_val_train.min()),2)
cross_val_train_min = round(-(cross_val_train.max()),2)

#Test Results
cross_val_test_mean = round(-(cross_val_test.mean()),2)
cross_val_test_max = round(-(cross_val_test.min()),2)
cross_val_test_min = round(-(cross_val_test.max()),2)

#Creating a Dataframe to display Validation Results
results_att = pd.DataFrame(columns=['Train/Test','Avg RMSE','Max RMSE','Min RMSE'])
results_att.loc[0] = ['Train',cross_val_train_mean,cross_val_train_max,cross_val_train_min]
results_att.loc[1] = ['Test', cross_val_test_mean, cross_val_test_max, cross_val_test_min]

# %%
fig, ax = plt.subplots(figsize=(20,12))

x_ticks = list(range(0,int(max(results_att['Max RMSE'])+1000000),2500000))
y_ticks = [1,2,3,4]
y_labels = ['Train Max RMSE','Train Min RMSE','Test Max RMSE','Test Min RMSE']

train_max_pos = 1
train_max = results_att.iloc[0][2]
ax.barh(train_max_pos,train_max,color='navy')

train_min_pos = 2
train_min = results_att.iloc[0][3]
ax.barh(train_min_pos,train_min,color='navy')

test_max_pos = 3
test_max = results_att.iloc[1][2]
ax.barh(test_max_pos,test_max,color='orange')

test_min_pos = 4
test_min = results_att.iloc[1][3]
ax.barh(test_min_pos,test_min,color='orange')

ax.axvline(x = results_att.iloc[0][1],label = 'Average Train RMSE',color='dodgerblue')
ax.axvline(x = results_att.iloc[1][1],label = 'Average Test RMSE',color='red')

ax.set_yticks(y_ticks)
ax.set_yticklabels(y_labels)
ax.set_xticks(x_ticks)
ax.set_xticklabels([f'£ {a}' for a in x_ticks])
ax.set_xlabel('Error Value in GBP (£)',fontsize=20)
ax.set_ylabel('Validation Results',fontsize=20)
ax.set_title('Support Vector Regression Results',fontsize=30)
ax.legend(fontsize=15);

# %%
results_att
# Out:
#   Train/Test  Avg RMSE  Max RMSE  Min RMSE
# 0      Train     11.48     13.05      8.63
# 1       Test     22.44     27.34     14.52

# %%
y_pred=svr_Grid.predict(X_test_scaled)
# Add the predicted labels to the test dataframe
test_data['label'] = y_pred
# Save the test dataframe with predictions to a CSV file
test_data.to_csv('Value prediction.csv', index=False)

# %%
selected_columns = test_data[['id', 'label']]

# Specify the path where you want to save the CSV file
csv_file_path = "Value prediction_grid.csv"

# Save the selected columns to a CSV file
selected_columns.to_csv(csv_file_path, index=False)

# %%
y_test
# Out:
# 351       3.5
# 486      12.0
# 599     150.0
# 442      15.0
# 270       8.0
#         ...
# 136       3.0
# 310      25.0
# 1078      5.0
# 532       5.0
# 411       1.0
# Name: Value at beginning of 2023/24 season, Length: 409, dtype: float64

# %%
from sklearn.metrics import mean_squared_error, r2_score
print("R2 Score: ", r2_score(y_test,y_pred)
# Out:
#   Cell In[36], line 2
#     print("R2 Score: ", r2_score(y_test,y_pred)
#                                                ^
# SyntaxError: incomplete input
